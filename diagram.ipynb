# %%
import spacy
from spacy import displacy
model='en_core_web_sm'
nlp = spacy.load(model)
doc = nlp(u'Amid escalating tensions that are damaging economic and diplomatic ties between the countries, Saudi Arabia said Monday that it would relocate about 7,000 Saudi scholarship recipients studying in Canada.')
spans = list(doc.ents) + list(doc.noun_chunks)
#for span in spans:
    #span.merge()
displacy.render(doc, style='dep', jupyter=True)
[t.ent_iob_ for t in doc]
#give_subtree = doc[5].subtree
#[t.text for t in give_subtree]
#give_ancestors = doc[0].ancestors
#[t.text for t in give_ancestors]
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="5125" height="662.0" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Amid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">escalating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">tensions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# ...

# %%
doc[2].ent_type_
# Out:
# 'MONEY'

# %%
import spacy
from spacy import displacy
model='en_core_web_sm'
nlp = spacy.load(model)
doc = nlp('Amid escalating tensions that are damaging economic and diplomatic ties between the countries, Saudi Arabia said Monday that it would relocate about 7,000 Saudi scholarship recipients studying in Canada.')
spans = list(doc.ents) + list(doc.noun_chunks)
for span in spans:
    span.merge()
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">Amid escalating tensions that are damaging economic and diplomatic ties between the countries,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Saudi Arabia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that it would relocate
# ...
