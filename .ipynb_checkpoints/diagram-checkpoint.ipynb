# %%
import spacy
from spacy import displacy
model='en_core_web_sm'
nlp = spacy.load(model)
doc = nlp(u'Early Sunday morning, the two were taken from the HaSharon prison in central Israel to a West Bank border crossing, then on to their village of Nabi Saleh and released.')
spans = list(doc.ents) + list(doc.noun_chunks)
#for span in spans:
    #span.merge()
displacy.render(doc, style='dep', jupyter=True)
[t.ent_iob_ for t in doc]
#give_subtree = doc[5].subtree
#[t.text for t in give_subtree]
#give_ancestors = doc[0].ancestors
#[t.text for t in give_ancestors]
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="5300" height="837.0" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Early</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Sunday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">morning,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# ...

# %%
doc[2].ent_type_
# Out:
# 'MONEY'

# %%
import spacy
from spacy import displacy
model='en_core_web_sm'
nlp = spacy.load(model)
doc = nlp('I like New York in Autumn.')
spans = list(doc.ents) + list(doc.noun_chunks)
#for span in spans:
    #span.merge()
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">I like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Autumn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>
